# %%
# connection to Rds Aws using sql connector

import os
import pymysql
import pandas as pd
conn = pymysql.connect(
    host='transaction-instance.c9zdxn3lynuz.us-east-1.rds.amazonaws.com',
    port=int(3306),
    user="admin",
    passwd='Rupesh162451',
    db="covid19database",
    charset='utf8mb4')

df = pd.read_sql_query("SELECT * FROM covid19",
    conn)
# Out:
# C:\Users\rupes\AppData\Local\Temp\ipykernel_13468\1400989613.py:14: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.

# %%
df
# Out:
#                            State                  District  Confirmed  Active  \
# 0    Andaman and Nicobar Islands                  Nicobars       2560     852
# 1    Andaman and Nicobar Islands  North and Middle Andaman       4567    5424
# 2    Andaman and Nicobar Islands             South Andaman        457    6523
# 3    Andaman and Nicobar Islands                   Unknown      10724       8
# 4                 Andhra Pradesh                 Anantapur     177614    8016
# ..                           ...                       ...        ...     ...
# 763                  West Bengal           Purba Medinipur      67849      29
# 764                  West Bengal                   Purulia      24235      26
# 765                  West Bengal         South 24 Parganas     127340     115
# 766                  West Bengal                   Unknown     102121    -793
# 767                  West Bengal            Uttar Dinajpur      25148      31
#
#      Recovered  Deceased
# ...

# %%
df.columns
# Out:
# Index(['State', 'District', 'Confirmed', 'Active', 'Recovered', 'Deceased'], dtype='object')

# %%
# import pymysql

# import pandas as a

# conn=pymysql.connect(host='transaction-instance.c9zdxn3lynuz.us-east-1.rds.amazonaws.com',port=int(3306),user='admin',passwd='Rupesh162451',db='covid19database')

# df=a.read_sql_query("SELECT * FROM covid21 ",conn)

# print(df)

# %%
pd.read_sql_query("SELECT * FROM covid19",conn)
# Out:
# C:\Users\rupes\AppData\Local\Temp\ipykernel_13468\1926362557.py:1: UserWarning:
#
# pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#                            State                  District  Confirmed  Active  \
# 0    Andaman and Nicobar Islands                  Nicobars       2560     852
# 1    Andaman and Nicobar Islands  North and Middle Andaman       4567    5424
# 2    Andaman and Nicobar Islands             South Andaman        457    6523
# 3    Andaman and Nicobar Islands                   Unknown      10724       8
# 4                 Andhra Pradesh                 Anantapur     177614    8016
# ..                           ...                       ...        ...     ...
# 763                  West Bengal           Purba Medinipur      67849      29
# 764                  West Bengal                   Purulia      24235      26
# ...

# %%
df
# Out:
#                            State                  District  Confirmed  Active  \
# 0    Andaman and Nicobar Islands                  Nicobars       2560     852
# 1    Andaman and Nicobar Islands  North and Middle Andaman       4567    5424
# 2    Andaman and Nicobar Islands             South Andaman        457    6523
# 3    Andaman and Nicobar Islands                   Unknown      10724       8
# 4                 Andhra Pradesh                 Anantapur     177614    8016
# ..                           ...                       ...        ...     ...
# 763                  West Bengal           Purba Medinipur      67849      29
# 764                  West Bengal                   Purulia      24235      26
# 765                  West Bengal         South 24 Parganas     127340     115
# 766                  West Bengal                   Unknown     102121    -793
# 767                  West Bengal            Uttar Dinajpur      25148      31
#
#      Recovered  Deceased
# ...

# %%
import plotly.express as px
fig = px.scatter(df, x="State", y="Confirmed", color="District",
                  hover_data=['State'])
fig.show()
# Out:
# <div>                            <div id="6a6f72cd-9ec7-40c5-9490-79b188a2c052" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a6f72cd-9ec7-40c5-9490-79b188a2c052")) {                    Plotly.newPlot(                        "6a6f72cd-9ec7-40c5-9490-79b188a2c052",                        [{"hovertemplate":"District=Nicobars<br>State=%{x}<br>Confirmed=%{y}<extra></extra>","legendgroup":"Nicobars","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Nicobars","orientation":"v","showlegend":true,"x":["Andaman and Nicobar Islands"],"xaxis":"x","y":[2560],"yaxis":"y","type":"scatter"},{"hovertemplate":"District=North and Middle Andaman<br>State=%{x}<br>Confirmed=%{y}<extra></extra>","legendgroup":"North and Middle Andaman","marker":{
# ...

# %%
import plotly.express as px
fig = px.scatter(df, x="State", y="Active", color="District",
                  hover_data=['State'])
fig.show()
# Out:
# <div>                            <div id="cf115023-ffbc-4ac7-ba86-e543c6ed2bb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf115023-ffbc-4ac7-ba86-e543c6ed2bb3")) {                    Plotly.newPlot(                        "cf115023-ffbc-4ac7-ba86-e543c6ed2bb3",                        [{"hovertemplate":"District=Nicobars<br>State=%{x}<br>Active=%{y}<extra></extra>","legendgroup":"Nicobars","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Nicobars","orientation":"v","showlegend":true,"x":["Andaman and Nicobar Islands"],"xaxis":"x","y":[852],"yaxis":"y","type":"scatter"},{"hovertemplate":"District=North and Middle Andaman<br>State=%{x}<br>Active=%{y}<extra></extra>","legendgroup":"North and Middle Andaman","marker":{"color"
# ...

# %%
import plotly.express as px
fig = px.scatter(df, x="State", y="Recovered", color="District",
                  hover_data=['State'])
fig.show()
# Out:
# <div>                            <div id="65d2035e-427f-4065-8b78-6f25e9a5aa02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65d2035e-427f-4065-8b78-6f25e9a5aa02")) {                    Plotly.newPlot(                        "65d2035e-427f-4065-8b78-6f25e9a5aa02",                        [{"hovertemplate":"District=Nicobars<br>State=%{x}<br>Recovered=%{y}<extra></extra>","legendgroup":"Nicobars","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Nicobars","orientation":"v","showlegend":true,"x":["Andaman and Nicobar Islands"],"xaxis":"x","y":[84],"yaxis":"y","type":"scatter"},{"hovertemplate":"District=North and Middle Andaman<br>State=%{x}<br>Recovered=%{y}<extra></extra>","legendgroup":"North and Middle Andaman","marker":{"c
# ...
